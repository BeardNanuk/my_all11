# %% [markdown]
# ## Quick comparison of signals in two su files

# %%
import sys
import obspy
import numpy as np
from seisflows.plugins import adjoint, misfit, readers, writers
from scipy.fftpack import fft, ifft
import matplotlib.pyplot as plt
from obspy.core import Stream, Trace

# define seismic data reader and writer
reader = getattr(readers,'su')
writer = getattr(writers, 'su')

#plot data
plot=1
plt_num = 10

data1 = reader('obf/input/','Up_sp_istf6_rec61_f050000.su')

data2 = reader('obf/input/','Upfreqmin1freqmax100000emFan01_SRC08_ts350_mat.su')

data3 = reader('obf/input/','Upfreqmin1freqmax100000Fan01_SRC08_mat_2500.su')


# data2 = reader('obf/input/','Up_sp_istf_watt2Q100_f0500000.su')
#output = reader('obf/output/','data_diff.su')

output = data2.copy()

# %%
data1[1]
# Out:
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T01:36:39.000000Z | 1.0 Hz, 5800 samples

# %%
data2[1]
# Out:
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:00:02.319600Z | 2500.0 Hz, 5800 samples

# %%
data3[1].data
# Out:
# array([3.5880554e-10, 3.5880565e-10, 3.5880576e-10, ..., 3.4961788e-16,
#        7.7421776e-17, 8.6656872e-18], dtype=float32)

# %%
plt.plot(data2[1].data)

# %%
data1
# Out:
# 61 Trace(s) in Stream:
#
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T01:36:39.000000Z | 1.0 Hz, 5800 samples
# ...
# (59 other traces)
# ...
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T01:36:39.000000Z | 1.0 Hz, 5800 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]

# %%
#statistics
# we make stats only on significant portions of the data : if the data is below 1/10000 of the max of the trace, we don't use it
stats=1
tol=0.00001
num_traces = len(data1)
NSTEP = len(data1[0].data)
vec_stat = np.zeros(num_traces)

step_star = 0
step_end = 5800
# for i in range(0,1):
for i in range(0,num_traces):
   #data1[i].taper(max_percentage=0.05,type='hann')
   output[i].data = data1[i].data - data2[i].data 
   output[i].stats.delta=0.01
   max1 = max(abs(data1[i].data))
   max2 = max(abs(data2[i].data))
   
   max_diff = max(abs(output[i].data))
   print ''
   print 'trace ' + str(i) 
   print 'Max 1st sample : ' + str(max1)
   print 'Max 2nd sample : ' + str(max2) 
   print 'Max discrepancy (infinite norm) : ' +  str(max_diff)
   print 'Ratio of infinite norms : ' +  str(max_diff/min(max1,max2))
   if (plot == 1):
    if (i % plt_num == 0):
      plt.plot(data1[i].data[step_star:step_end], '-g',label='synthetic empty')
      plt.plot(data2[i].data[step_star:step_end], '-r',label='filtered empty real data')
      #plt.plot(data3[i].data[step_star:step_end], '-m',label='filtered nonempty real data')
      #plt.plot(output[i].data[step_star:step_end],'-b',label='difference')
      plt.legend(['synthetic empty','filtered empty real data','filtered nonempty real data'])
      plt.show()

#   if (stats == 1):
#     max12 = tol * min(max1,max2)
#     n_dat = 0 
#     for j in range(0,NSTEP):
#         if ( min(abs(data1[i].data[j]),abs(data2[i].data[j])) > max12 ) :
#           vec_stat[i] =  abs( output[i].data[j] / max(abs(data1[i].data[j]),abs(data2[i].data[j])) )
#           print  output[i].data[j] , data1[i].data[j], data2[i].data[j], vec_stat[i]
#           n_dat += 1
#     if (n_dat > 0):
#       vec_stat[i] /= n_dat
#     print 'Ecart standard : ' + str(vec_stat[i]*100) + ' %, based on ' + str(n_dat) + ' evaluation points'

#if (plot == 1):
# if (stats == 1):
#   plot(vec_stat)

#output.write('obf/output/data_diff.su',format='SU')
# Out:
# trace 0
# Max 1st sample : 0.007977485
# Max 2nd sample : 0.00010564138
# Max discrepancy (infinite norm) : 0.007977445
# Ratio of infinite norms : 75.51439
# trace 1
# Max 1st sample : 0.007969414
# Max 2nd sample : 0.0002117471
# Max discrepancy (infinite norm) : 0.007969578
# Ratio of infinite norms : 37.637245
#
# trace 2
# Max 1st sample : 0.007961268
# Max 2nd sample : 0.00016048813
# Max discrepancy (infinite norm) : 0.007961417
# Ratio of infinite norms : 49.607513
# trace 3
# Max 1st sample : 0.007952224
# Max 2nd sample : 0.0003287662
# Max discrepancy (infinite norm) : 0.007952099
# Ratio of infinite norms : 24.1877
#
# trace 4
# Max 1st sample : 0.007943594
# Max 2nd sample : 0.0001717642
# Max discrepancy (infinite norm) : 0.007943594
# Ratio of infinite norms : 46.247086
# trace 5
# Max 1st sample : 0.007933635
# Max 2nd sample : 0.00020716974
# Max discrepancy (infinite norm) : 0.007933635
# Ratio of infinite norms : 38.295338
#
# trace 6
# Max 1st sample : 0.00792455
# ...

# %%
data2
# Out:
# 61 Trace(s) in Stream:
#
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:00:02.319600Z | 2500.0 Hz, 5800 samples
# ...
# (59 other traces)
# ...
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:00:02.319600Z | 2500.0 Hz, 5800 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]

# %%
plt_num = 2
for i in range(0,61,1):
   #data1[i].taper(max_percentage=0.05,type='hann')

   if (plot == 1):
    if (i % plt_num == 0):
      plt.plot(data1[i].data[step_star:step_end]/max(data1[i].data[step_star:step_end]), '-g',label='synthetic empty')
      plt.plot(data2[i].data[step_star:step_end]/max(data2[i].data[step_star:step_end]), '-r',label='filtered empty real data')
      #plt.plot(data3[i].data[step_star:step_end]/max(data3[i].data[step_star:step_end]), '-m',label='filtered nonempty real data')
      #plt.plot(output[i].data[step_star:step_end],'-b',label='difference')
      plt.legend(['trace number is ' + str(i)])
      #plt.legend(['synthetic empty','filtered empty real data','filtered nonempty real data'])
      plt.show()

# %%
data2
# Out:
# 61 Trace(s) in Stream:
#
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:00:02.319600Z | 2500.0 Hz, 5800 samples
# ...
# (59 other traces)
# ...
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:00:02.319600Z | 2500.0 Hz, 5800 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
